# %% [markdown]
# intergração de SQL com python

# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc
import pandas as pd

dados_conexao = (
"Driver={SQL Server};"
"Server=AURUM;"
"Database=THEMIS_KLEBER";
)

conexao = pyodbc.connect (dados_conexao)
print("conexão bem sucedida")
# Out:
#   Cell In[5], line 7
#     "Database=THEMIS_KLEBER";
#                             ^
# SyntaxError: invalid syntax

# %%
import pyodbc
import pandas as pd

dados_conexao = (
"Driver={SQLServer};"
"Server=AURUM\SQL2019;"
"Database=THEMIS_KLEBER";
)

conexao = pyodbc.connect (dados_conexao)
print("conexão bem sucedida")
# Out:
#   Cell In[6], line 7
#     "Database=THEMIS_KLEBER";
#                             ^
# SyntaxError: invalid syntax

# %%
import pyodbc
import pandas as pd

dados_conexao = (
    "Driver={SQLServer};"
    "Server=AURUM\\SQL2019;"
    "Database=THEMIS_KLEBER"
)

conexao = pyodbc.connect(dados_conexao)
print("conexão bem sucedida")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[7], line 10
#       2 import pandas as pd
#       4 dados_conexao = (
#       5     "Driver={SQLServer};"
#       6     "Server=AURUM\\SQL2019;"
#       7     "Database=THEMIS_KLEBER"
#       8 )
# ---> 10 conexao = pyodbc.connect(dados_conexao)
#      11 print("conexão bem sucedida")
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Nome da fonte de dados não encontrado e nenhum driver padrão especificado (0) (SQLDriverConnect)')

# %%
import pyodbc
import pandas as pd

dados_conexao = (
    "Driver={SQL Server};"
    "Server=AURUM\\SQL2019;"
    "Database=THEMIS_KLEBER"
)

conexao = pyodbc.connect(dados_conexao)
print("conexão bem sucedida")
# Out:
# conexão bem sucedida

# %%
comando_sql = "select id_processo, pasta , numproc, titproc, status, DATA_ENTRADA, DATA_INICIO, DATA_ENCER from processo"

dados = pd.read_sql(comando_sql,conexao)
# Out:
# C:\Users\Kleber Parigi\AppData\Local\Temp\ipykernel_21604\3540773664.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dados = pd.read_sql(comando_sql,conexao)

# %%
display(dados)
# Out:
#       id_processo       pasta                    numproc  \
# 0               4   0001-2017           2008.026.49625-0
# 1               6        0059  0000251-95.2010.5.01.0072
# 2               7        0005  0021300-22.2007.5.01.0001
# 3               8        0020                     141731
# 4              11        0026  0000535-98.2010.4.02.5168
# ...           ...         ...                        ...
# 1829         2659  Civel-2164  0013576-28.2016.8.10.0040
# 1830         2660  Civel-2165       23070200001003413-01
# 1831         2661    Civel-11  0500099-36.2017.8.05.0022
# 1832         2663    Civel-13  0005312-77.2014.8.08.0030
# 1833         2664    Civel-14  0005862-84.2015.8.08.0047
#
#                                                 titproc status DATA_ENTRADA  \
# 0     Thiago Costa e outros x Anita Coimbra do Nasci...      1   2006-02-16
# 1                   Rock & Soul Ltda x Carlos Von Stein      0   2008-02-02
# ...

# %%
dados.groupby(status).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dados.groupby(status).count()
#
# NameError: name 'status' is not defined

# %%
dados.groupby(status)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dados.groupby(status)
#
# NameError: name 'status' is not defined

# %%
display(dados)
# Out:
#       id_processo       pasta                    numproc  \
# 0               4   0001-2017           2008.026.49625-0
# 1               6        0059  0000251-95.2010.5.01.0072
# 2               7        0005  0021300-22.2007.5.01.0001
# 3               8        0020                     141731
# 4              11        0026  0000535-98.2010.4.02.5168
# ...           ...         ...                        ...
# 1829         2659  Civel-2164  0013576-28.2016.8.10.0040
# 1830         2660  Civel-2165       23070200001003413-01
# 1831         2661    Civel-11  0500099-36.2017.8.05.0022
# 1832         2663    Civel-13  0005312-77.2014.8.08.0030
# 1833         2664    Civel-14  0005862-84.2015.8.08.0047
#
#                                                 titproc status DATA_ENTRADA  \
# 0     Thiago Costa e outros x Anita Coimbra do Nasci...      1   2006-02-16
# 1                   Rock & Soul Ltda x Carlos Von Stein      0   2008-02-02
# ...

# %%
dados.groupby(data_entrada)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dados.groupby(data_entrada)
#
# NameError: name 'data_entrada' is not defined

# %%
dados.groupby(status).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dados.groupby(status).count()
#
# NameError: name 'status' is not defined

# %%
dados.orderby(status).count(status = '1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21604\2763975582.py in ?()
# ----> 1 dados.orderby(status).count(status = '1')
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'orderby'

# %%
import pandas as pd

# %%
display(dados)
# Out:
#       id_processo       pasta                    numproc  \
# 0               4   0001-2017           2008.026.49625-0
# 1               6        0059  0000251-95.2010.5.01.0072
# 2               7        0005  0021300-22.2007.5.01.0001
# 3               8        0020                     141731
# 4              11        0026  0000535-98.2010.4.02.5168
# ...           ...         ...                        ...
# 1829         2659  Civel-2164  0013576-28.2016.8.10.0040
# 1830         2660  Civel-2165       23070200001003413-01
# 1831         2661    Civel-11  0500099-36.2017.8.05.0022
# 1832         2663    Civel-13  0005312-77.2014.8.08.0030
# 1833         2664    Civel-14  0005862-84.2015.8.08.0047
#
#                                                 titproc status DATA_ENTRADA  \
# 0     Thiago Costa e outros x Anita Coimbra do Nasci...      1   2006-02-16
# 1                   Rock & Soul Ltda x Carlos Von Stein      0   2008-02-02
# ...

# %%
comando_sql = "select p.id_processo, a.NM_AREA as area,p.pasta, p.numproc, p.titproc, case when p.status = '1' then 'Encerrado' else 'Ativo' end as status,p.DATA_ENTRADA,p.DATA_INICIO,p.DATA_ENCER from processo p left join area a on a.id_area=p.id_area"

dados2 = pd.read_sql(comando_sql,conexao)
# Out:
# C:\Users\Kleber Parigi\AppData\Local\Temp\ipykernel_21604\3420929880.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dados2 = pd.read_sql(comando_sql,conexao)

# %%
display(dados2)
# Out:
#       id_processo      NM_AREA       pasta                    numproc  \
# 0               4  Trabalhista   0001-2017           2008.026.49625-0
# 1               6        Cível        0059  0000251-95.2010.5.01.0072
# 2               7  Trabalhista        0005  0021300-22.2007.5.01.0001
# 3               8  Trabalhista        0020                     141731
# 4              11        Cível        0026  0000535-98.2010.4.02.5168
# ...           ...          ...         ...                        ...
# 1829         2659        Cível  Civel-2164  0013576-28.2016.8.10.0040
# 1830         2660        Cível  Civel-2165       23070200001003413-01
# 1831         2661        Cível    Civel-11  0500099-36.2017.8.05.0022
# 1832         2663        Cível    Civel-13  0005312-77.2014.8.08.0030
# 1833         2664        Cível    Civel-14  0005862-84.2015.8.08.0047
#
#                                                 titproc     status  \
# ...

# %%
dados2.groupby(nm_area).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dados2.groupby(nm_area).count()
#
# NameError: name 'nm_area' is not defined

# %%
dados2.groupby(nm_area).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 dados2.groupby(nm_area).count()
#
# NameError: name 'nm_area' is not defined

# %%
resultado_agrupado = dados2.groupby('nm_area').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 resultado_agrupado = dados2.groupby('nm_area').count()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
comando_sql = "select p.id_processo, a.NM_AREA as area,p.pasta, p.numproc, p.titproc, case when p.status = '1' then 'Encerrado' else 'Ativo' end as status,p.DATA_ENTRADA,p.DATA_INICIO,p.DATA_ENCER from processo p left join area a on a.id_area=p.id_area"

dados3 = pd.read_sql(comando_sql,conexao)
# Out:
# C:\Users\Kleber Parigi\AppData\Local\Temp\ipykernel_21604\1428072369.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dados3 = pd.read_sql(comando_sql,conexao)

# %%
display(dados3)
# Out:
#       id_processo         area       pasta                    numproc  \
# 0               4  Trabalhista   0001-2017           2008.026.49625-0
# 1               6        Cível        0059  0000251-95.2010.5.01.0072
# 2               7  Trabalhista        0005  0021300-22.2007.5.01.0001
# 3               8  Trabalhista        0020                     141731
# 4              11        Cível        0026  0000535-98.2010.4.02.5168
# ...           ...          ...         ...                        ...
# 1829         2659        Cível  Civel-2164  0013576-28.2016.8.10.0040
# 1830         2660        Cível  Civel-2165       23070200001003413-01
# 1831         2661        Cível    Civel-11  0500099-36.2017.8.05.0022
# 1832         2663        Cível    Civel-13  0005312-77.2014.8.08.0030
# 1833         2664        Cível    Civel-14  0005862-84.2015.8.08.0047
#
#                                                 titproc     status  \
# ...

# %%
dados3.groupby(area).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dados3.groupby(area).count()
#
# NameError: name 'area' is not defined

# %%
dados3.groupby(status).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dados3.groupby(status).count()
#
# NameError: name 'status' is not defined

# %%
dados3.groupby(status)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 dados3.groupby(status)
#
# NameError: name 'status' is not defined

# %%
df.dados3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.dados3
#
# NameError: name 'df' is not defined

# %%
df=dados3

# %%
display(df)
# Out:
#       id_processo         area       pasta                    numproc  \
# 0               4  Trabalhista   0001-2017           2008.026.49625-0
# 1               6        Cível        0059  0000251-95.2010.5.01.0072
# 2               7  Trabalhista        0005  0021300-22.2007.5.01.0001
# 3               8  Trabalhista        0020                     141731
# 4              11        Cível        0026  0000535-98.2010.4.02.5168
# ...           ...          ...         ...                        ...
# 1829         2659        Cível  Civel-2164  0013576-28.2016.8.10.0040
# 1830         2660        Cível  Civel-2165       23070200001003413-01
# 1831         2661        Cível    Civel-11  0500099-36.2017.8.05.0022
# 1832         2663        Cível    Civel-13  0005312-77.2014.8.08.0030
# 1833         2664        Cível    Civel-14  0005862-84.2015.8.08.0047
#
#                                                 titproc     status  \
# ...

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
dados3.groupby(area).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 dados3.groupby(area).count()
#
# NameError: name 'area' is not defined

# %%
resultado_agrupado = dados3.groupby('area').count()

# %%
display(resultado_agrupado)
# Out:
#                               id_processo  pasta  numproc  titproc  status  \
# area
# Administração                           5      5        5        5       5
# Ambiental                              14     14       14       14      14
# Aurum                                   2      2        2        2       2
# Cobrança                                1      1        1        1       1
# Criminal                                3      3        3        3       3
# Cível                                 309    307      297      309     309
# Direito Imobiliário                     2      2        2        2       2
# Eleitoral                               7      6        7        7       7
# Internacional                           1      1        1        1       1
# Penal                                   4      4        4        4       4
# Prestação de Serviço11112225            1      1        1        1       1
# ...

# %%
df.resultado_agrupado
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21604\3323763129.py in ?()
# ----> 1 df.resultado_agrupado
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'resultado_agrupado'

# %%
df=resultado_agrupado

# %%
display(df)
# Out:
#                               id_processo  pasta  numproc  titproc  status  \
# area
# Administração                           5      5        5        5       5
# Ambiental                              14     14       14       14      14
# Aurum                                   2      2        2        2       2
# Cobrança                                1      1        1        1       1
# Criminal                                3      3        3        3       3
# Cível                                 309    307      297      309     309
# Direito Imobiliário                     2      2        2        2       2
# Eleitoral                               7      6        7        7       7
# Internacional                           1      1        1        1       1
# Penal                                   4      4        4        4       4
# Prestação de Serviço11112225            1      1        1        1       1
# ...

# %%
df.plot(kind="bar")
# Out:
# <Axes: xlabel='area'>
