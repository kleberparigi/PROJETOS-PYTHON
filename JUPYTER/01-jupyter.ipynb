# %%
print ("Coringão Campeão. O melhor de todos!")
# Out:
# Coringão Campeão. O melhor de todos!

# %% [markdown]
# observação argumento descrição para orientação.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install powerbiclient
# Out:
# ...
#   Obtaining dependency information for powerbiclient from https://files.pythonhosted.org/packages/95/06/6ca62f807ed6a441d31ab179e708deefa544d128d067aa45e34b39df0728/powerbiclient-3.1.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for msal>=1.8.0 from https://files.pythonhosted.org/packages/b7/61/2756b963e84db6946e4b93a8e288595106286fc11c7129fcb869267ead67/msal-1.26.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      --------------------------------------- 0.3/316.9 MB 10.2 MB/s eta 0:00:31
#      --------------------------------------- 0.8/316.9 MB 10.6 MB/s eta 0:00:30
#      --------------------------------------- 1.7/316.9 MB 13.5 MB/s eta 0:00:24
#      --------------------------------------- 2.8/316.9 MB 16.4 MB/s eta 0:00:20
#      --------------------------------------- 3.9/316.9 MB 17.5 MB/s eta 0:00:18
#       -------------------------------------- 4.9/316.9 MB 18.3 MB/s eta 0:00:18
# ...

# %%
from powerbiclient import Report, models
